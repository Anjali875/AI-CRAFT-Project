# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Data/PCOS_data (2).csv")
df.head()
# Out:
#    Sl. No  Patient File No. PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1         No          28         44.6        152.0
# 1       2                 2         No          36         65.0        161.5
# 2       3                 3        Yes          33         68.8        165.0
# 3       4                 4         No          37         65.0        148.0
# 4       5                 5         No          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.3           15                78                22  ...
# 1  24.9           15                74                20  ...
# 2  25.3           11                72                18  ...
# 3  29.7           13                72                20  ...
# 4  20.1           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0              1.0                  0                  110
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ANJALI\OneDrive\Desktop\AI CRAFT\notebooks
